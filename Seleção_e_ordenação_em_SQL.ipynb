# %% [markdown]
# <a href="https://colab.research.google.com/github/iamttom/AWS_S3-AWS_Athena/blob/main/Sele%C3%A7%C3%A3o_e_ordena%C3%A7%C3%A3o_em_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

files = [
    '/content/m31query1.csv.csv',
    '/content/m31query2.csv.csv',
    '/content/m31query3.csv.csv',
    '/content/m31query4.csv.csv'
]

for file in files:
  print(f"Contents of {file}:")
  try:
    df = pd.read_csv(file)
    display(df)
  except Exception as e:
    print(f"Could not read {file}: {e}")
  print("-" * 30)
# Out:
# Contents of /content/m31query1.csv.csv:
#    id_cliente         valor  id_loja
# 0           2  7.688054e+08    30.90
# 1           3  8.187700e+08   110.00
# 2           1  7.685656e+07  2000.90
# 3           1  7.675738e+08    15.70
# 4           3  8.185758e+08     2.99
# 5           4  7.645455e+08    50.74
# 6           5  7.676679e+07    10.00
# 7           3  8.154568e+09  1100.00
# ------------------------------
# Contents of /content/m31query2.csv.csv:
#                         id_cliente         valor  nome_loja
# 0                              NaN           NaN        NaN
# 1                              NaN           NaN        NaN
# 2                      id_cliente*           NaN        NaN
# 3                              NaN           NaN        NaN
# 4   hive"valor*valor2double8@           NaN        NaN
# 5                              NaN           NaN        NaN
# 6                                2  7.688054e+08      30.90
# ...
