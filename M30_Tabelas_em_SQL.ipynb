# %% [markdown]
# <a href="https://colab.research.google.com/github/iamttom/AWS_S3-AWS_Athena/blob/main/M30_Tabelas_em_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_query6 = pd.read_csv('/content/mod30_query6.csv')
display(df_query6.head())
# Out:
#   sexo  total_clientes  media_limite
# 0    F               3      2.333333
# 1    M               3      4.000000

# %%
import pandas as pd

df_query5 = pd.read_csv('/content/mod30_query5.csv')
display(df_query5.head())
# Out:
#           id  idade  limite_credito  escolaridade estado_civil  qtde_filhos  \
# 0     456556     30             0.0      mestrado     solteiro         5526
# 1        545     49             2.0     doutorado         blue         3417
# 2  818770008     49             5.0      mestrado     solteiro         8256
# 3  768805451     56             6.0  ensino medio       casado         7591
# 4  768805383     45             3.0  ensino medio         blue        12691
#
#   sexo
# 0    F
# 1    F
# 2    F
# 3    M
# 4    M

# %%
import pandas as pd

df_query3 = pd.read_csv('/content/mod30_query3.csv')
display(df_query3.head())
# Out:
#    sexo  media_limite
# 0    45           3.0
# 1    51           3.0
# 2    30           0.0
# 3    49           3.5
# 4    56           6.0

# %%
import pandas as pd

df_query4 = pd.read_csv('/content/mod30_query4.csv')
display(df_query4.head())
# Out:
#    total_registros
# 0                6

# %%
import pandas as pd

df_query2 = pd.read_csv('/content/mod30_query2.csv')
display(df_query2.head())
# Out:
# Empty DataFrame
# Columns: [id, sexo, idade, limite_credito]
# Index: []

# %%
import pandas as pd

df = pd.read_csv('/content/mod30_query1.csv')
display(df.head())
# Out:
#           id  sexo  idade  limite_credito  escolaridade estado_civil  \
# 0  768805451    56    NaN             6.0  ensino medio       casado
# 1     456556    30    NaN             0.0      mestrado     solteiro
# 2        545    49    NaN             2.0     doutorado         blue
# 3  768805383    45    NaN             3.0  ensino medio         blue
# 4  818770008    49    NaN             5.0      mestrado     solteiro
#
#    qtde_filhos
# 0         7591
# 1         5526
# 2         3417
# 3        12691
# 4         8256

# %%
import pandas as pd

query7 = pd.read_csv("/content/query_7.csv.csv")
display(query7.head())
# Out:
#           id  sexo  idade  limite_credito  escolaridade estado_civil  \
# 0  768805383    45    NaN             3.0  ensino medio         blue
# 1  818770008    49    NaN             5.0      mestrado     solteiro
# 2  713982108    51    NaN             3.0      mestrado       casado
# 3  768805451    56    NaN             6.0  ensino medio       casado
# 4     456556    30    NaN             0.0      mestrado     solteiro
#
#    qtde_filhos  renda_anual
# 0        12691      1144.90
# 1         8256      1291.45
# 2         3418      1887.72
# 3         7591      1564.90
# 4         5526     55251.45
