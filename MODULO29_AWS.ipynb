# %% [markdown]
# <a href="https://colab.research.google.com/github/iamttom/AWS_S3-AWS_Athena/blob/main/MODULO29_AWS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Load the data from "query_1.csv", "query_2.csv", and "query_3.csv" into separate dataframes and display the first few rows of each dataframe.

# %% [markdown]
# ## Load csv files
#
# ### Subtask:
# Load each CSV file (`query_1.csv`, `query_2.csv`, and `query_3.csv`) into a separate pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# The subtask requires loading three CSV files into separate dataframes. This can be done by importing the pandas library and then using the `read_csv` function for each file.

# %%
import pandas as pd

df_query1 = pd.read_csv('/content/query_1.csv')
df_query2 = pd.read_csv('/content/query_2.csv')
df_query3 = pd.read_csv('/content/query_3.csv')

# %% [markdown]
# ## Display dataframes
#
# ### Subtask:
# Display the head of each DataFrame to verify the data has been loaded correctly.

# %% [markdown]
# **Reasoning**:
# Display the head of each DataFrame to verify the data has been loaded correctly.

# %%
display(df_query1.head())
display(df_query2.head())
display(df_query3.head())
# Out:
#           id  sexo  idade  limite_credito  escolaridade estado_civil  \
# 0  768805383    45    NaN             3.0  ensino medio         blue
# 1  818770008    49    NaN             5.0      mestrado     solteiro
# 2  713982108    51    NaN             3.0      mestrado       casado
#
#    qtde_filhos
# 0        12691
# 1         8256
# 2         3418
#           id  idade  limite_credito
# 0  768805383    NaN             3.0
# 1  713982108    NaN             3.0
#    sexo  media_idade_por_sexo
# 0    49                   NaN
# 1    45                   NaN
# 2    51                   NaN

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The three CSV files, `query_1.csv`, `query_2.csv`, and `query_3.csv`, were successfully loaded into separate pandas DataFrames named `df_query1`, `df_query2`, and `df_query3`, respectively.
# *   The first few rows of `df_query1` were displayed, showing columns such as `id`, `sexo`, `idade`, `limite_credito`, `escolaridade`, `estado_civil`, and `qtde_filhos`.
# *   The first few rows of `df_query2` were displayed, showing columns such as `id`, `idade`, and `limite_credito`.
# *   The first few rows of `df_query3` were displayed, showing columns such as `sexo` and `media_idade_por_sexo`.
#
# ### Insights or Next Steps
#
# *   The data loading and initial inspection were successful for all three datasets.
# *   The next step could involve exploring the data further, such as checking data types, identifying missing values, and performing descriptive statistics on each dataframe.
